# %% [markdown]
# basics of python
# calculator
# library... numpy, pandas, matplotlib
# seaborn,sklearn, tensorflow, re, nltk,
#  basics of python
#  calculator
#  basic data type
#  variable
#  container type:- list tuple, set ,dictinory
#
#  Indexing and slicing
#  membership operation

# %%
print("Hello World")
# Out:
# Hello World

# %%
x=5
print(x*5)
# Out:
# 25

# %%
x=3
y=5
print(x*y)
print(x**y)
print(x+y)
print(x-y)
# Out:
# 15
# 243
# 8
# -2

# %%
t = True
f = Falseprint(type(t))
print(t and f)
print (t or f)
print not tprint(t!= f)
# Out:
#   File "/tmp/ipykernel_866/2149880636.py", line 5
#     print not tprint(t!= f)
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
xs = [3 ,1, 2]
print(xs, xs[2])
xs[2] = 'foo'
print(xs)
xs.append('bar')
print(xs)
x = xs.pop()
print(x, xs)
# Out:
# [3, 1, 2] 2
# [3, 1, 'foo']
# [3, 1, 'foo', 'bar']
# bar [3, 1, 'foo']

# %%
nums = list(range(5))
print(nums)
print(nums[2:4])
print(nums[2:])
print(nums[:2])
print(nums[:])
print(nums[:-1])
nums[2:4] = [8,9]
print(nums)
# Out:
# [0, 1, 2, 3, 4]
# [2, 3]
# [2, 3, 4]
# [0, 1]
# [0, 1, 2, 3, 4]
# [0, 1, 2, 3]
# [0, 1, 8, 9, 4]

# %%
myT =("Daawer","Wasiullah","retesh","tessica")

# %%
mylist =["Daawer","Wasiullah","retesh","tessica"]
type(mylist)
# Out:
# list

# %%
mySet =("Daawer","Wasiullah","retesh","tessica")
type(mySet)
# Out:
# tuple

# %%
myS ={"Daawer","Wasiullah","retesh","tessica"}
type(myS)
# Out:
# set
